# %%
import pandas as pd

df = pd.read_json("data/data.json")

# %%
df
# Out:
#      Email Number                   Intent Category  \
# 0               1          Intent_Lease_Abstraction
# 1               2          Intent_Lease_Abstraction
# 2               3          Intent_Lease_Abstraction
# 3               4          Intent_Lease_Abstraction
# 4               5          Intent_Lease_Abstraction
# ..            ...                               ...
# 155           156  Intent_Lease_Listings_Comparison
# 156           157  Intent_Lease_Listings_Comparison
# 157           158  Intent_Lease_Listings_Comparison
# 158           159  Intent_Lease_Listings_Comparison
# 159           160  Intent_Lease_Listings_Comparison
#
#                                     Intent Description  \
# 0    Extract lease metadata and clauses (e.g., rent...
# 1    Extract lease metadata and clauses (e.g., rent...
# 2    Extract lease metadata and clauses (e.g., rent...
# 3    Extract lease metadata and clauses (e.g., rent...
# 4    Extract lease metadata and clauses (e.g., rent...
# ...

# %%
df.to_csv("data/data.csv", index=False)
